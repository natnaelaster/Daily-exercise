# %%
import pandas as pd
import glob

# %%
datas = glob.glob(r"*.csv")
#for data in datas:
datas
# Out:
# ['accounts.csv',
#  'data_dictionary.csv',
#  'products.csv',
#  'sales_pipeline.csv',
#  'sales_teams.csv']

# %%
acc = pd.read_csv('accounts.csv')
print(acc.columns)
dic = pd.read_csv('data_dictionary.csv')
print(f"dic{dic.columns}")
pro = pd.read_csv('products.csv')
print(pro.columns)
sales_p = pd.read_csv('sales_pipeline.csv')
print(sales_p.columns)
sales_t = pd.read_csv('sales_teams.csv')
print(sales_t.columns)
# Out:
# Index(['account', 'sector', 'year_established', 'revenue', 'employees',
#        'office_location', 'subsidiary_of'],
#       dtype='str')
# dicIndex(['Table', 'Field', 'Description'], dtype='str')
# Index(['product', 'series', 'sales_price'], dtype='str')
# Index(['opportunity_id', 'sales_agent', 'product', 'account', 'deal_stage',
#        'engage_date', 'close_date', 'close_value'],
#       dtype='str')
# Index(['sales_agent', 'manager', 'regional_office'], dtype='str')

# %%
print(acc['account'].unique())
print(sales_p['account'].unique())
# Out:
# <StringArray>
# [            'Acme Corporation',                   'Betasoloin',
#                      'Betatech',                   'Bioholding',
#                       'Bioplex',                     'Blackzim',
#                 'Bluth Company',                   'Bubba Gump',
#                       'Cancity',                       'Cheers',
#                       'Codehow',                       'Condax',
#                       'Conecom',               'Dalttechnology',
#                       'dambase',                      'Domzoom',
#                        'Doncon',                  'Donquadtech',
#                      'Dontechi',                      'Donware',
#                    'Fasehatice',                     'Faxquote',
#                       'Finhigh',                       'Finjob',
#                    'Funholding',                    'Ganjaflex',
#                    'Gekko & Co', 'Genco Pura Olive Oil Company',
# ...

# %%
print(pro['product'].nunique())
print(sales_p['product'].nunique())
# Out:
# 7
# 7

# %%
print(sales_t['sales_agent'].nunique())
print(sales_p['sales_agent'].nunique())
# Out:
# 35
# 30
